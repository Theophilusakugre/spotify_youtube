# %% [markdown]
# ## Problem Statement

# %% [markdown]
# ## About Dataset
# Dataset of songs of various artist in the world and for each song is present:
#
# Several statistics of the music version on spotify, including the number of streams;
# Number of views of the official music video of the song on youtube.
# Content
# It includes 26 variables for each of the songs collected from spotify. These variables are briefly described next:
#
# * Track: name of the song, as visible on the Spotify platform.
# * Artist: name of the artist.
# * Url_spotify: the Url of the song.
# * Album: the album in wich the song is contained on Spotify.
# * Album_type: indicates if the song is relesead on Spotify as a single or contained in an album.
# * Uri: a spotify link used to find the song through the API.
# * Danceability: describes how suitable a track is for dancing based on a combination of musical elements including tempo, rhythm stability, beat strength, and overall regularity. A value of 0.0 is least danceable and 1.0 is most danceable.
# * Energy: is a measure from 0.0 to 1.0 and represents a perceptual measure of intensity and activity. Typically, energetic tracks feel fast, loud, and noisy. For example, death metal has high energy, while a Bach prelude scores low on the scale. Perceptual features contributing to this attribute include dynamic range, perceived loudness, timbre, onset rate, and general entropy.
# * Key: the key the track is in. Integers map to pitches using standard Pitch Class notation. E.g. 0 = C, 1 = C♯/D♭, 2 = D, and so on. If no key was detected, the value is -1.
# * Loudness: the overall loudness of a track in decibels (dB). Loudness values are averaged across the entire track and are useful for comparing relative loudness of tracks. Loudness is the quality of a sound that is the primary psychological correlate of physical strength (amplitude). Values typically range between -60 and 0 db.
# * Speechiness: detects the presence of spoken words in a track. The more exclusively speech-like the recording (e.g. talk show, audio book, poetry), the closer to 1.0 the attribute value. Values above 0.66 describe tracks that are probably made entirely of spoken words. Values between 0.33 and 0.66 describe tracks that may contain both music and speech, either in sections or layered, including such cases as rap music. Values below 0.33 most likely represent music and other non-speech-like tracks.
# * Acousticness: a confidence measure from 0.0 to 1.0 of whether the track is acoustic. 1.0 represents high confidence the track is acoustic.
# * Instrumentalness: predicts whether a track contains no vocals. "Ooh" and "aah" sounds are treated as instrumental in this context. Rap or spoken word tracks are clearly "vocal". The closer the instrumentalness value is to 1.0, the greater likelihood the track contains no vocal content. Values above 0.5 are intended to represent instrumental tracks, but confidence is higher as the value approaches 1.0.
# * Liveness: detects the presence of an audience in the recording. Higher liveness values represent an increased probability that the track was performed live. A value above 0.8 provides strong likelihood that the track is live.
# * Valence: a measure from 0.0 to 1.0 describing the musical positiveness conveyed by a track. Tracks with high valence sound more positive (e.g. happy, cheerful, euphoric), while tracks with low valence sound more negative (e.g. sad, depressed, angry).
# * Tempo: the overall estimated tempo of a track in beats per minute (BPM). In musical terminology, tempo is the speed or pace of a given piece and derives directly from the average beat duration.
# * Duration_ms: the duration of the track in milliseconds.
# * Stream: number of streams of the song on Spotify.
# * Url_youtube: url of the video linked to the song on Youtube, if it have any.
# * Title: title of the videoclip on youtube.
# * Channel: name of the channel that have published the video.
# * Views: number of views.
# * Likes: number of likes.
# * Comments: number of comments.
# * Description: description of the video on Youtube.
# * Licensed: Indicates whether the video represents licensed content, which means that the content was uploaded to a channel linked to a YouTube content partner and then claimed by that partner.
# * official_video: boolean value that indicates if the video found is the official video of the song.
# ## Notes
# These datas are heavily dependent on the time they were collected, which is in this case the 7th of February, 2023.

# %% [markdown]
# ## Import  Libraries

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import matplotlib

# %%
# change the default fontsize to 14 for my visuals
matplotlib.rcParams['font.size']=14

# %%
sns.set_style('darkgrid')

# %% [markdown]
# ## Load Dataset

# %%
data = pd.read_csv("Spotify_Youtube.csv",index_col=0)
data.head()
# Out:
#      Artist                                        Url_spotify  \
# 0  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 3  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 4  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
#
#                                            Track  \
# 0                                 Feel Good Inc.
# 1                                Rhinestone Eyes
# 2  New Gold (feat. Tame Impala and Bootie Brown)
# 3                             On Melancholy Hill
# 4                                 Clint Eastwood
#
#                                            Album Album_type  \
# 0                                     Demon Days      album
# 1                                  Plastic Beach      album
# 2  New Gold (feat. Tame Impala and Bootie Brown)     single
# ...

# %% [markdown]
# Knowing the columns i'm working with

# %%
data.columns
# Out:
# Index(['Artist', 'Url_spotify', 'Track', 'Album', 'Album_type', 'Uri',
#        'Danceability', 'Energy', 'Key', 'Loudness', 'Speechiness',
#        'Acousticness', 'Instrumentalness', 'Liveness', 'Valence', 'Tempo',
#        'Duration_ms', 'Url_youtube', 'Title', 'Channel', 'Views', 'Likes',
#        'Comments', 'Description', 'Licensed', 'official_video', 'Stream'],
#       dtype='object')

# %% [markdown]
# Having a feel of how a row of this data is.

# %%
data.loc[0]
# Out:
# Artist                                                       Gorillaz
# Url_spotify         https://open.spotify.com/artist/3AA28KZvwAUcZu...
# Track                                                  Feel Good Inc.
# Album                                                      Demon Days
# Album_type                                                      album
# Uri                              spotify:track:0d28khcov6AiegSCpG5TuT
# Danceability                                                    0.818
# Energy                                                          0.705
# Key                                                               6.0
# Loudness                                                       -6.679
# Speechiness                                                     0.177
# Acousticness                                                  0.00836
# Instrumentalness                                              0.00233
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20718 entries, 0 to 20717
# Data columns (total 27 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Artist            20718 non-null  object
#  1   Url_spotify       20718 non-null  object
#  2   Track             20718 non-null  object
#  3   Album             20718 non-null  object
#  4   Album_type        20718 non-null  object
#  5   Uri               20718 non-null  object
#  6   Danceability      20716 non-null  float64
#  7   Energy            20716 non-null  float64
#  8   Key               20716 non-null  float64
#  9   Loudness          20716 non-null  float64
#  10  Speechiness       20716 non-null  float64
#  11  Acousticness      20716 non-null  float64
#  12  Instrumentalness  20716 non-null  float64
#  13  Liveness          20716 non-null  float64
#  14  Valence           20716 non-null  float64
#  15  Tempo             20716 non-null  float64
# ...

# %% [markdown]
# The dataset contains 20718 rows, with 27 columns of 2 datatypes thus float and object <br>
# There are missing data in a few columns

# %% [markdown]
# Knowing which columns has missing data

# %%
data.isna().sum()
# Out:
# Artist                0
# Url_spotify           0
# Track                 0
# Album                 0
# Album_type            0
# Uri                   0
# Danceability          2
# Energy                2
# Key                   2
# Loudness              2
# Speechiness           2
# Acousticness          2
# Instrumentalness      2
# Liveness              2
# Valence               2
# Tempo                 2
# Duration_ms           2
# Url_youtube         470
# Title               470
# Channel             470
# Views               470
# Likes               541
# Comments            569
# Description         876
# Licensed            470
# official_video      470
# Stream              576
# dtype: int64

# %% [markdown]
# ## Dealing with missing data

# %% [markdown]
# * Dropping NA in views, which tends to solve for title,channel,url_youtube,licensed and official_video
# * Dropping NA in stream
# * Filling NA in likes with 0
# * Filling NA in comments with 0
# * Filling NA  in description with No Description
# * Finally dropping NA in the remaining columns

# %%
data = data[data['Views'].notna()]

# %%
data = data[data['Stream'].notna()]

# %%
data['Likes'] = data['Likes'].fillna(0)

# %%
data['Comments'] = data['Comments'].fillna(0)

# %%
data['Description'] = data['Description'].fillna('No Description')

# %%
data.dropna(inplace=True)

# %%
data.isna().sum()
# Out:
# Artist              0
# Url_spotify         0
# Track               0
# Album               0
# Album_type          0
# Uri                 0
# Danceability        0
# Energy              0
# Key                 0
# Loudness            0
# Speechiness         0
# Acousticness        0
# Instrumentalness    0
# Liveness            0
# Valence             0
# Tempo               0
# Duration_ms         0
# Url_youtube         0
# Title               0
# Channel             0
# Views               0
# Likes               0
# Comments            0
# Description         0
# Licensed            0
# official_video      0
# Stream              0
# dtype: int64

# %%
data.describe()
# Out:
#        Danceability        Energy           Key      Loudness   Speechiness  \
# count  19691.000000  19691.000000  19691.000000  19691.000000  19691.000000
# mean       0.620921      0.634793      5.294094     -7.641455      0.095205
# std        0.165452      0.213700      3.578829      4.620160      0.106113
# min        0.000000      0.000020      0.000000    -46.251000      0.000000
# 25%        0.519000      0.508000      2.000000     -8.785500      0.035700
# 50%        0.639000      0.666000      5.000000     -6.518000      0.050500
# 75%        0.742000      0.797000      8.000000     -4.931000      0.104000
# max        0.975000      1.000000     11.000000      0.920000      0.964000
#
#        Acousticness  Instrumentalness      Liveness       Valence  \
# count  19691.000000      19691.000000  19691.000000  19691.000000
# mean       0.289590          0.055433      0.191155      0.529019
# std        0.286253          0.192739      0.165137      0.245487
# ...

# %%
data.select_dtypes('object').columns
# Out:
# Index(['Artist', 'Url_spotify', 'Track', 'Album', 'Album_type', 'Uri',
#        'Url_youtube', 'Title', 'Channel', 'Description', 'Licensed',
#        'official_video'],
#       dtype='object')

# %%
print("Columns" +'   '+'number of uninique values ')
for col in data.select_dtypes('object').columns:
    print(col, ': ',data[col].nunique())
# Out:
# Columns   number of uninique values
# Artist :  2041
# Url_spotify :  2041
# Track :  16992
# Album :  11442
# Album_type :  3
# Uri :  17966
# Url_youtube :  17676
# Title :  17670
# Channel :  6549
# Description :  16940
# Licensed :  2
# official_video :  2

# %% [markdown]
# Checking if we have duplicated rows

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Want to check specifically if tracks are duplicated

# %%
data[data.Track.duplicated()]
# Out:
#                Artist                                        Url_spotify  \
# 141            Khalid  https://open.spotify.com/artist/6LuN9FCkKOj5Pc...
# 155           Shakira  https://open.spotify.com/artist/0EmeFodog0BfCg...
# 248         Lil Wayne  https://open.spotify.com/artist/55Aa2cqylxrFIX...
# 296            Tiësto  https://open.spotify.com/artist/2o5jDhtHVPhrJd...
# 312             JAY-Z  https://open.spotify.com/artist/3nFkdlSjzX9mRT...
# ...               ...                                                ...
# 20662          AYLIVA  https://open.spotify.com/artist/2rEVnwCPBeGkWM...
# 20672  Grupo Frontera  https://open.spotify.com/artist/6XkjpgcEsYab50...
# 20673  Grupo Frontera  https://open.spotify.com/artist/6XkjpgcEsYab50...
# 20675  Grupo Frontera  https://open.spotify.com/artist/6XkjpgcEsYab50...
# 20679  Grupo Frontera  https://open.spotify.com/artist/6XkjpgcEsYab50...
#
#                        Track  \
# 141                     Numb
# ...

# %% [markdown]
# Verifying if a duplicated track is by the same artist. <br>
# A duplicated track does'nt mean the whole row is duplicated, it only mean the several artist named their tracks same name.

# %%
data[data['Track']== "Vete"]
# Out:
#                Artist                                        Url_spotify  \
# 7236           Rafaga  https://open.spotify.com/artist/0CBKUzrf6yGdTg...
# 14627  Alfredo Olivas  https://open.spotify.com/artist/5xYNmNkaWRqu3e...
# 17099     Omar Varela  https://open.spotify.com/artist/5xIOUIBQhGFX7H...
# 19413            KHEA  https://open.spotify.com/artist/4m6ubhNsdwF4ps...
# 19771     Kevin Kaarl  https://open.spotify.com/artist/6OBGbSaBUvQtk9...
# 20679  Grupo Frontera  https://open.spotify.com/artist/6XkjpgcEsYab50...
#
#       Track         Album Album_type                                   Uri  \
# 7236   Vete   Una Cerveza      album  spotify:track:5PBglLuGrJFWg7Z3mRqFYi
# 14627  Vete  ALFA & OMEGA      album  spotify:track:1GtIK8iINes4gNt06F60NU
# 17099  Vete          Vete     single  spotify:track:0BMXB8USeC2zVufRWBcMuY
# 19413  Vete          Vete     single  spotify:track:0BMXB8USeC2zVufRWBcMuY
# 19771  Vete     San Lucas      album  spotify:track:1KIt07Xn6PVFVEyQnwCyCt
# ...

# %% [markdown]
# Dropping url columns

# %%
data.drop(['Url_spotify','Url_youtube'],axis=1,inplace=True)

# %%
# set the display format for floats to include commas
pd.options.display.float_format = '{:,.0f}'.format

# %% [markdown]
# ## Analysis

# %%
data.groupby(['Artist'])['Views','Likes','Comments'].sum().reset_index().sort_values(by='Views',ascending=False).head(10)
# Out:
# C:\Users\MTL9\AppData\Local\Temp\ipykernel_15004\1798123549.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data.groupby(['Artist'])['Views','Likes','Comments'].sum().reset_index().sort_values(by='Views',ascending=False).head(10)
#                        Artist          Views      Likes  Comments
# 516                Ed Sheeran 15,460,207,769 83,543,319 2,520,822
# 368                 CoComelon 14,601,671,211 41,713,913         0
# 936                Katy Perry 13,120,632,075 63,067,090 3,153,267
# 329              Charlie Puth 12,167,594,191 86,336,925 3,723,796
# 1130               Luis Fonsi 11,628,113,031 66,908,489 4,703,428
# 909             Justin Bieber 10,991,060,236 78,584,348 7,259,120
# 415              Daddy Yankee 10,871,926,842 65,518,171 4,672,128
# 263                Bruno Mars 10,240,919,227 59,616,146 1,924,316
# 1164  Macklemore & Ryan Lewis 10,122,055,560 66,041,410 2,425,190
# ...

# %% [markdown]
# **Which artist had the most views on YouTube?**

# %%
views_df = data.groupby(['Artist'])['Views'].sum().reset_index().sort_values(by='Views',ascending=False).head(10)

# %%
data.groupby(['Artist'])['Views'].sum().reset_index().sort_values(by='Views',ascending=False).head(10)
# Out:
#                        Artist          Views
# 516                Ed Sheeran 15,460,207,769
# 368                 CoComelon 14,601,671,211
# 936                Katy Perry 13,120,632,075
# 329              Charlie Puth 12,167,594,191
# 1130               Luis Fonsi 11,628,113,031
# 909             Justin Bieber 10,991,060,236
# 415              Daddy Yankee 10,871,926,842
# 263                Bruno Mars 10,240,919,227
# 1164  Macklemore & Ryan Lewis 10,122,055,560
# 375                  Coldplay  9,997,277,884

# %%
plt.figure(figsize=(10,5))
plt.title('Top Artist Based on YouTube Views')
ax = sns.barplot(data=views_df, y='Artist', x='Views', orient='h', palette='Greens')
plt.xlabel('Views in Billions')
plt.ylabel('')
for p in ax.patches:
    value = p.get_width() / 1000000000
    ax.text(p.get_width() + 0.1, p.get_y() + 0.5 * p.get_height(), f'{value:.1f}B', ha='left', va='center')

plt.show()

# %% [markdown]
# **Which artist had the most likes on YouTube?**

# %%
likes_df = data.groupby(['Artist'])['Likes'].sum().reset_index().sort_values(by='Likes',ascending=False).head(10)

# %%
data.groupby(['Artist'])['Likes'].sum().reset_index().sort_values(by='Likes',ascending=False).head(10)
# Out:
#                Artist       Likes
# 151               BTS 139,403,808
# 149         BLACKPINK 132,302,505
# 329      Charlie Puth  86,336,925
# 516        Ed Sheeran  83,543,319
# 909     Justin Bieber  78,584,348
# 199     Billie Eilish  73,338,537
# 765   Imagine Dragons  72,274,477
# 59        Alan Walker  67,977,702
# 411          DJ Snake  67,775,831
# 1130       Luis Fonsi  66,908,489

# %%
plt.figure(figsize=(10,5))
plt.title('Artist With Most Likes on YouTube')
ax = sns.barplot(data=likes_df, y='Artist', x='Likes', orient='h', palette='Greens')
plt.xlabel('Likes in Millions')
plt.ylabel('')
for p in ax.patches:
    value = p.get_width() / 1000000
    ax.text(p.get_width() + 0.1, p.get_y() + 0.5 * p.get_height(), f'{value:.1f}M', ha='left', va='center')

plt.show()

# %% [markdown]
# **Which artist had the most comments on YouTube?**

# %%
comments_df = data.groupby(['Artist'])['Comments'].sum().reset_index().sort_values(by='Comments',ascending=False).head(10)

# %%
data.groupby(['Artist'])['Comments'].sum().reset_index().sort_values(by='Comments',ascending=False).head(10)
# Out:
#              Artist   Comments
# 151             BTS 39,542,659
# 149       BLACKPINK 19,605,027
# 1723     Stray Kids  8,458,365
# 1752          TWICE  8,384,985
# 1411            PSY  7,311,608
# 909   Justin Bieber  7,259,120
# 509             EXO  6,981,950
# 715          Halsey  6,981,661
# 1391  One Direction  6,360,892
# 1130     Luis Fonsi  4,703,428

# %%
plt.figure(figsize=(10,5))
plt.title('Top Artist Based on YouTube Comments')
ax = sns.barplot(data=comments_df, y='Artist', x='Comments', orient='h', palette='Greens')
plt.xlabel('Comments in Millions')
plt.ylabel('')
for p in ax.patches:
    value = p.get_width() / 1000000
    ax.text(p.get_width() + 0.1, p.get_y() + 0.5 * p.get_height(), f'{value:.1f}M', ha='left', va='center')

plt.show()

# %%
data.columns
# Out:
# Index(['Artist', 'Track', 'Album', 'Album_type', 'Uri', 'Danceability',
#        'Energy', 'Key', 'Loudness', 'Speechiness', 'Acousticness',
#        'Instrumentalness', 'Liveness', 'Valence', 'Tempo', 'Duration_ms',
#        'Title', 'Channel', 'Views', 'Likes', 'Comments', 'Description',
#        'Licensed', 'official_video', 'Stream'],
#       dtype='object')

# %% [markdown]
# **Which artist had the most engagements on YouTube?**

# %%
data['Engagements'] = data['Likes'] * data['Comments']

# %%
data.groupby(['Artist'])['Engagements'].sum().reset_index().sort_values(by='Engagements',ascending=False).head(10)
# Out:
#              Artist           Engagements
# 151             BTS 1,066,135,266,852,433
# 149       BLACKPINK   372,518,307,161,324
# 415    Daddy Yankee   221,029,648,116,986
# 1130     Luis Fonsi   219,497,706,737,933
# 715          Halsey   182,478,173,515,865
# 1411            PSY   154,682,670,864,957
# 909   Justin Bieber   136,954,440,145,035
# 329    Charlie Puth    99,218,015,852,274
# 1960    Wiz Khalifa    87,596,952,200,323
# 1712     Steve Aoki    61,310,518,338,555

# %%
engagements_df = data.groupby(['Artist'])['Engagements'].sum().reset_index().sort_values(by='Engagements',ascending=False).head(10)

# %%
plt.figure(figsize=(10,5))
plt.title('Artist with the most engagements on Youtube')
ax = sns.barplot(data=engagements_df, y='Artist', x='Engagements', orient='h', palette='Greens')
plt.xlabel('Engagements in Billions')
plt.ylabel('')
for p in ax.patches:
    value = p.get_width() / 1000000000000
    ax.text(p.get_width() + 0.1, p.get_y() + 0.5 * p.get_height(), f'{value:.1f}B', ha='left', va='center')

plt.show()

# %% [markdown]
# **Which artist had the most streams on Spotify?**

# %%
stream_df = data.groupby(['Artist'])['Stream'].sum().reset_index().sort_values(by='Stream',ascending=False).head(10)

# %%
data.groupby(['Artist'])['Stream'].sum().reset_index().sort_values(by='Stream',ascending=False).head(10)
# Out:
#                Artist         Stream
# 1471      Post Malone 15,251,263,853
# 516        Ed Sheeran 14,394,881,557
# 497          Dua Lipa 13,408,076,274
# 1966     XXXTENTACION 13,224,351,699
# 1830       The Weeknd 13,031,973,376
# 909     Justin Bieber 12,097,767,422
# 765   Imagine Dragons 11,858,310,928
# 375          Coldplay 11,778,478,236
# 963            Khalid 11,386,839,915
# 263        Bruno Mars 10,897,862,950

# %%
plt.figure(figsize=(10,5))
plt.title('Top Artist Based on Sportify Streams')
ax = sns.barplot(data=stream_df, y='Artist', x='Stream', orient='h', palette='Greens')
plt.xlabel('Stream in Billions')
plt.ylabel('')
for p in ax.patches:
    value = p.get_width() / 1000000000
    ax.text(p.get_width() + 0.1, p.get_y() + 0.5 * p.get_height(), f'{value:.1f}B', ha='left', va='center')

plt.show()

# %% [markdown]
# **Which album_type had the most views and streams on YouTube and Spotify respectively?**

# %%
album_views = data.groupby(['Album_type'])['Views'].sum().reset_index().sort_values(by='Views',ascending=False).head(10)

# %%
data.groupby(['Album_type'])['Views'].sum().reset_index().sort_values(by='Views',ascending=False).head(10)
# Out:
#     Album_type             Views
# 0        album 1,417,487,399,294
# 2       single   395,102,245,194
# 1  compilation    58,972,823,620

# %%
album_stream = data.groupby(['Album_type'])['Stream'].sum().reset_index().sort_values(by='Stream',ascending=False).head(10)

# %%
data.groupby(['Album_type'])['Stream'].sum().reset_index().sort_values(by='Stream',ascending=False).head(10)
# Out:
#     Album_type            Stream
# 0        album 2,150,663,962,571
# 2       single   484,641,747,430
# 1  compilation    60,986,736,312

# %%
plt.figure(figsize=(20,10))
plt.subplot(1,2,1)
plt.title('Album_type with More Views on YouTube')
total = sum(album_views['Views'])
cr=['#7E3A8F','#3A8D8F','#8F8D3A5E']
plt.pie(album_views['Views'],labels=album_views['Album_type'],colors=cr,explode=[0,0,0.1],
        autopct=lambda pct: f'{pct:.1f}% \n({int(pct/100*total):,})')
plt.legend(loc='lower center', ncol=3, bbox_to_anchor=(0.5, -0.01))

plt.subplot(1,2,2)
plt.title('Album_type with More Streams on Spotify')
total = sum(album_stream['Stream'])
cr=['#7E3A8F','#3A8D8F','#8F8D3A5E']
plt.pie(album_stream['Stream'],labels=album_views['Album_type'],colors=cr,explode=[0,0,0.1],
        autopct=lambda pct: f'{pct:.1f}% \n({int(pct/100*total):,})')
plt.legend(loc='lower center', ncol=3, bbox_to_anchor=(0.5, -0.01))
;
# Out:
# ''

# %% [markdown]
# **Does the key of a song affects its views and streams on YouTube and Spotify respectively?**

# %%
key_views_df = data.groupby(['Key'])['Views'].sum().reset_index().sort_values(by='Views',ascending=False)

# %%
data.groupby(['Key'])['Views'].sum().reset_index().sort_values(by='Views',ascending=False)
# Out:
#     Key           Views
# 1     1 210,697,775,672
# 0     0 205,225,671,335
# 11   11 177,435,813,522
# 7     7 175,359,372,027
# 5     5 167,368,488,127
# 2     2 167,162,511,453
# 9     9 154,515,929,169
# 6     6 147,627,817,775
# 8     8 145,843,914,621
# 10   10 142,378,546,664
# 4     4 123,627,834,702
# 3     3  54,318,793,041

# %%
key_stream_df = data.groupby(['Key'])['Stream'].sum().reset_index().sort_values(by='Stream',ascending=False)

# %%
data.groupby(['Key'])['Stream'].sum().reset_index().sort_values(by='Stream',ascending=False)
# Out:
#     Key          Stream
# 1     1 329,764,022,611
# 0     0 307,279,810,971
# 7     7 263,856,278,994
# 2     2 240,139,388,382
# 11   11 239,709,210,907
# 5     5 229,568,207,558
# 9     9 225,038,990,520
# 8     8 203,775,134,735
# 6     6 202,026,089,588
# 4     4 189,733,901,282
# 10   10 184,057,628,022
# 3     3  81,343,782,743

# %%
plt.figure(figsize=(20,10))
plt.subplot(1,2,1)
plt.title('YouTube Views based on Keys')
ax = sns.barplot(data=key_views_df, y='Key', x='Views',orient='h', palette='Greens')
plt.xlabel('Views in Billions')
plt.ylabel('')
for p in ax.patches:
    value = p.get_width() / 1000000000
    ax.text(p.get_width() + 0.1, p.get_y() + 0.5 * p.get_height(), f'{value:.1f}B', ha='left', va='center')

plt.subplot(1,2,2)
plt.title('Spotify Streams based on Keys')
ax = sns.barplot(data=key_stream_df, y='Key', x='Stream',orient='h', palette='Greens')
plt.xlabel('Streams in Billions')
plt.ylabel('')
for p in ax.patches:
    value = p.get_width() / 1000000000
    ax.text(p.get_width() + 0.1, p.get_y() + 0.5 * p.get_height(), f'{value:.1f}B', ha='left', va='center')

plt.show()

# %% [markdown]
# ## Defining functions that i will use the create the helper columns

# %%
def danceability(x):
    '''Danceability: describes how suitable a track is for dancing based on a combination of musical elements including tempo,
    rhythm stability, beat strength, and overall regularity.
    A value of 0.0 is least danceable and 1.0 is most danceable.'''
    if x >= 0.7:
        return "Very Danceable"
    elif x >=0.4:
        return "Moderately danceable"
    else:
        return "Less danceable"

# %%
danceability(0.8)
# Out:
# 'Very Danceable'

# %%
def energy(x):
    '''Energy: is a measure from 0.0 to 1.0 and represents a perceptual measure of intensity and activity. 
    Typically, energetic tracks feel fast, loud, and noisy. 
    For example, death metal has high energy, while a Bach prelude scores low on the scale.
    Perceptual features contributing to this attribute include dynamic range, perceived loudness, 
    timbre, onset rate, and general entropy.'''
    if x >= 0.7:
        return 'High Energy'
    elif x >= 0.4:
        return 'Mid Energy'
    else:
        return 'Low Energy'

# %%
def valence(x):
    '''Valence: a measure from 0.0 to 1.0 describing the musical positiveness conveyed by a track. 
    Tracks with high valence sound more positive (e.g. happy, cheerful, euphoric),
    while tracks with low valence sound more negative (e.g. sad, depressed, angry).'''
    if x >= 0.7:
        return 'Positive'
    elif x >0.4:
        return 'Neutral'
    else:
        return 'Negative'

# %%
def liveness(x):
    '''Liveness: detects the presence of an audience in the recording. Higher liveness values represent an increased probability that the track was performed live. 
    A value above 0.8 provides strong likelihood that the track is live.'''
    if x >= 0.8:
        return 'Live'
    else:
        return 'Not Live'

# %%
def speechiness(x):
    '''Speechiness: detects the presence of spoken words in a track. 
    The more exclusively speech-like the recording (e.g. talk show, audio book, poetry), 
    the closer to 1.0 the attribute value.
    Values above 0.66 describe tracks that are probably made entirely of spoken words. 
    Values between 0.33 and 0.66 describe tracks that may contain both music and speech, 
    either in sections or layered, including such cases as rap music. 
    Values below 0.33 most likely represent music and other non-speech-like tracks.'''
    if x >= 0.66:
        return 'Spoken Words'
    elif x >= 0.33:
        return 'music and speech'
    else:
        return 'Non-Speech and Tracks'

# %%
data.columns
# Out:
# Index(['Artist', 'Track', 'Album', 'Album_type', 'Uri', 'Danceability',
#        'Energy', 'Key', 'Loudness', 'Speechiness', 'Acousticness',
#        'Instrumentalness', 'Liveness', 'Valence', 'Tempo', 'Duration_ms',
#        'Title', 'Channel', 'Views', 'Likes', 'Comments', 'Description',
#        'Licensed', 'official_video', 'Stream', 'Engagements'],
#       dtype='object')

# %% [markdown]
# ## Creating our helper columns

# %%
data['danceable'] = data['Danceability'].apply(danceability)

# %%
data['energy_type'] = data['Energy'].apply(energy)

# %%
data['song_mood'] = data['Valence'].apply(valence)

# %%
data['live'] = data['Liveness'].apply(liveness)

# %%
data['speech'] = data['Speechiness'].apply(speechiness)

# %%
data[['Artist','Track','Album_type','danceable','energy_type','song_mood',
      'live','speech','Title','Views', 'Likes', 'Comments', 'Description', 'Stream']].head(2)
# Out:
#      Artist            Track Album_type             danceable  energy_type  \
# 0  Gorillaz   Feel Good Inc.      album        Very Danceable  High Energy
# 1  Gorillaz  Rhinestone Eyes      album  Moderately danceable  High Energy
#
#   song_mood      live                 speech  \
# 0  Positive  Not Live  Non-Speech and Tracks
# 1  Positive  Not Live  Non-Speech and Tracks
#
#                                                Title       Views     Likes  \
# 0         Gorillaz - Feel Good Inc. (Official Video) 693,555,221 6,220,896
# 1  Gorillaz - Rhinestone Eyes [Storyboard Film] (...  72,011,645 1,079,128
#
#    Comments                                        Description        Stream
# 0   169,907  Official HD Video for Gorillaz' fantastic trac... 1,040,234,854
# 1    31,003  The official video for Gorillaz - Rhinestone E...   310,083,733

# %% [markdown]
# **Does the danceability of a song affects its views and streams?**

# %%
dance_df = data.groupby(['danceable'])[['Stream','Views']].sum().reset_index()

# %%
data.groupby(['danceable'])[['Stream','Views']].sum().reset_index()
# Out:
#               danceable            Stream           Views
# 0        Less danceable   203,662,107,720 108,407,072,972
# 1  Moderately danceable 1,434,019,330,918 908,321,423,751
# 2        Very Danceable 1,058,611,007,675 854,833,971,385

# %%
plt.figure(figsize=(20,15))
plt.subplot(1,2,1)
plt.title('Song_Mood with More Streams on Spotify')
total = sum(dance_df['Stream'])
cr=['#7E3A8F','#3A8D8F','#8F8D3A5E']
plt.pie(dance_df['Stream'],labels=dance_df['danceable'],colors=cr,explode=[0,0,0.],
        autopct=lambda pct: f'{pct:.1f}% \n({int(pct/100*total):,})')
plt.legend(loc='lower center', ncol=3, bbox_to_anchor=(0.5, -0.05))

plt.subplot(1,2,2)
plt.title('Song_Mood with More Views on YouTube')
total = sum(dance_df['Views'])
cr=['#7E3A8F','#3A8D8F','#8F8D3A5E']
plt.pie(dance_df['Views'],labels=dance_df['danceable'],colors=cr,explode=[0,0,0],
        autopct=lambda pct: f'{pct:.1f}% \n({int(pct/100*total):,})')
plt.legend(loc='lower center', ncol=3, bbox_to_anchor=(0.5, -0.05));

# %% [markdown]
# **Does the level of energy in a song affect its views and streams?**

# %%
energy_df = data.groupby(['energy_type'])[['Stream','Views']].sum().reset_index()

# %%
data.groupby(['energy_type'])[['Stream','Views']].sum().reset_index()
# Out:
#    energy_type            Stream           Views
# 0  High Energy 1,215,680,189,990 935,896,324,884
# 1   Low Energy   270,428,768,789 131,919,714,143
# 2   Mid Energy 1,210,183,487,534 803,746,429,081

# %%
plt.figure(figsize=(20,15))
plt.subplot(1,2,1)
plt.title('Songs energy_type with More Streams on Spotify')
total = sum(energy_df['Stream'])
cr=['#7E3A8F','#3A8D8F','#8F8D3A5E']
plt.pie(energy_df['Stream'],labels=energy_df['energy_type'],colors=cr,explode=[0,0,0.],
        autopct=lambda pct: f'{pct:.1f}% \n({int(pct/100*total):,})')
plt.legend(loc='lower center', ncol=3, bbox_to_anchor=(0.5, -0.05))

plt.subplot(1,2,2)
plt.title('Songs energy_type with More Views on YouTube')
total = sum(energy_df['Views'])
cr=['#7E3A8F','#3A8D8F','#8F8D3A5E']
plt.pie(energy_df['Views'],labels=energy_df['energy_type'],colors=cr,explode=[0,0,0],
        autopct=lambda pct: f'{pct:.1f}% \n({int(pct/100*total):,})')
plt.legend(loc='lower center', ncol=3, bbox_to_anchor=(0.5, -0.05))
;
# Out:
# ''

# %% [markdown]
# **Does the mood portrayed in a songs affects the songs views and streams?**

# %%
song_mood_df = data.groupby(['song_mood'])[['Stream','Views']].sum().reset_index()

# %%
data.groupby(['song_mood'])[['Stream','Views']].sum().reset_index()
# Out:
#   song_mood            Stream           Views
# 0  Negative   884,504,455,268 543,897,176,108
# 1   Neutral 1,103,650,276,959 732,479,610,786
# 2  Positive   708,137,714,086 595,185,681,214

# %%
plt.figure(figsize=(20,15))
plt.subplot(1,2,1)
plt.title('Song_Mood with More Streams on Spotify')
total = sum(song_mood_df['Stream'])
cr=['#7E3A8F','#3A8D8F','#8F8D3A5E']
plt.pie(song_mood_df['Stream'],labels=song_mood_df['song_mood'],colors=cr,explode=[0,0,0.],
        autopct=lambda pct: f'{pct:.1f}% \n({int(pct/100*total):,})')
plt.legend(loc='lower center', ncol=3, bbox_to_anchor=(0.5, -0.01))

plt.subplot(1,2,2)
plt.title('Song_Mood with More Views on YouTube')
total = sum(song_mood_df['Views'])
cr=['#7E3A8F','#3A8D8F','#8F8D3A5E']
plt.pie(song_mood_df['Views'],labels=song_mood_df['song_mood'],colors=cr,explode=[0,0,0],
        autopct=lambda pct: f'{pct:.1f}% \n({int(pct/100*total):,})')
plt.legend(loc='lower center', ncol=3, bbox_to_anchor=(0.5, -0.01))
;
# Out:
# ''

# %% [markdown]
# **Does songs that were recorded live get views and streams than the non-live ones?**

# %%
live_df = data.groupby(['live'])[['Stream','Views']].sum().reset_index()

# %%
data.groupby(['live'])[['Stream','Views']].sum().reset_index()
# Out:
#        live            Stream             Views
# 0      Live    21,015,467,152    21,575,983,914
# 1  Not Live 2,675,276,979,161 1,849,986,484,194

# %%
plt.figure(figsize=(20,15))
plt.subplot(1,2,1)
plt.title('Liveliness with More Streams on Spotify')
total = sum(live_df['Stream'])
cr=['#7E3A8F','#3A8D8F']
plt.pie(live_df['Stream'],labels=live_df['live'],colors=cr,
        autopct=lambda pct: f'{pct:.1f}% \n({int(pct/100*total):,})')
plt.legend(loc='lower center', ncol=3, bbox_to_anchor=(0.5, -0.01))

plt.subplot(1,2,2)
plt.title('Liveliness with More Views on YouTube')
total = sum(live_df['Views'])
cr=['#7E3A8F','#3A8D8F']
plt.pie(live_df['Views'],labels=live_df['live'],colors=cr,
        autopct=lambda pct: f'{pct:.1f}% \n({int(pct/100*total):,})')
plt.legend(loc='lower center', ncol=3, bbox_to_anchor=(0.5, -0.01))

;
# Out:
# ''

# %% [markdown]
# **Does a songs level of speechiness affects its views and streams?**

# %%
speech_df = data.groupby(['speech'])[['Stream','Views']].sum().reset_index()

# %%
data.groupby(['speech'])[['Stream','Views']].sum().reset_index()
# Out:
#                   speech            Stream             Views
# 0  Non-Speech and Tracks 2,590,134,724,950 1,812,932,761,624
# 1           Spoken Words       827,330,045       179,393,392
# 2       music and speech   105,330,391,318    58,450,313,092

# %%
plt.figure(figsize=(20,15))
plt.subplot(1,2,1)
plt.title('Speechiness with More Streams on Spotify')
total = sum(speech_df['Stream'])
cr=['#7E3A8F','#3A8D8F','#8F8D3A5E']
plt.pie(speech_df['Stream'],labels=speech_df['speech'],colors=cr,explode=[0,0.5,0.],
        autopct=lambda pct: f'{pct:.1f}% \n({int(pct/100*total):,})')
plt.legend(loc='lower center', ncol=3, bbox_to_anchor=(0.5, -0.01))

plt.subplot(1,2,2)
plt.title('Speechiness with More Views on YouTube')
total = sum(speech_df['Views'])
cr=['#7E3A8F','#3A8D8F','#8F8D3A5E']
plt.pie(speech_df['Views'],labels=speech_df['speech'],colors=cr,explode=[0,0.5,0],
        autopct=lambda pct: f'{pct:.1f}% \n({int(pct/100*total):,})')
plt.legend(loc='lower center', ncol=3, bbox_to_anchor=(0.5, -0.01))

;
# Out:
# ''
